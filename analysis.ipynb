# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/ecommerce_sales.csv")
print(df.head())
# Out:
#    OrderID Customer     Category Product  Quantity  Price
# 0     1001     Amit  Electronics  Laptop         1  55000
# 1     1002    Rahul  Electronics  Mobile         2  18000
# 2     1003    Priya      Fashion   Shoes         3   2500
# 3     1004     Neha      Fashion   Dress         2   1800
# 4     1005    Ankit         Home   Chair         4   3000

# %%
df['Revenue'] = df['Quantity'] * df['Price']
print("Total Revenue:", df['Revenue'].sum())
# Out:
# Total Revenue: 114100

# %%
top_products = df.groupby('Product')['Revenue'].sum().sort_values(ascending=False)
print("\nTop Products:\n", top_products)
# Out:
# Top Products:
#  Product
# Laptop    55000
# Mobile    36000
# Chair     12000
# Shoes      7500
# Dress      3600
# Name: Revenue, dtype: int64

# %%
category_revenue = df.groupby('Category')['Revenue'].sum().sort_values(ascending=False)
print("\nCategory Revenue:\n", category_revenue)
# Out:
# Category Revenue:
#  Category
# Electronics    91000
# Home           12000
# Fashion        11100
# Name: Revenue, dtype: int64

# %%
category_revenue.plot(kind='bar', title='Revenue by Category')
plt.ylabel('Revenue')
plt.tight_layout()
plt.show()
